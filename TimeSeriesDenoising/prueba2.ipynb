# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, figure, show
import numpy as np
import pandas as pd
import scipy.io as sio
import scipy.signal
from rich import print

# %%
df = pd.read_csv('prueba.csv', sep='\t')
df.head()
# Out:
#         t         F
# 0  18.524  3629.050
# 1  18.541  3630.728
# 2  18.558  3628.516
# 3  18.574  3629.202
# 4  18.591  3632.407

# %%
plt.figure(figsize=(18, 5))
plt.plot(df['t'], df['F'], marker='.', linestyle='None')
plt.show()
